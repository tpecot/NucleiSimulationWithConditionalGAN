# %% [markdown]
# ## Loading
#
# The first step is to load the functions from utils.

# %%
from utils import estimate_distributions, generate_images_with_ellipses

# %% [markdown]
# ## Estimate distributions for number of nuclei per image and nuclei sizes

# %%
# folder with input masks
input_mask_dir = './datasets/Nuclei_polyps/training/masks/'

# call function
avg_nb_nuclei, std_nb_nuclei, avg_nuclei_size = estimate_distributions(input_mask_dir)

# %% [markdown]
# ## Generate images with ellipses whose number and size follow the distributions previously estimated

# %%
# folder with input masks
output_masks_dir = './datasets/Simulated_masks/ellipses_100/'

# dimension for output masks
input_dim_x = 256
input_dim_y = 256

# total number of generated images
total_nb_images = 1000

# call function
generate_images_with_ellipses(input_dim_x, input_dim_y, total_nb_images, output_masks_dir, 
                              avg_nb_nuclei, std_nb_nuclei, avg_nuclei_size)
